# %%
import pandas as pd

# %%
df =pd.read_csv('Student_Marks.csv')

# %%
df.head()
# Out:
#    Hours  Marks
# 0   4.06  16.90
# 1   9.53  48.81
# 2   7.45  38.72
# 3   6.19  27.38
# 4   1.98  19.23

# %%
df.tail()
# Out:
#      Hours  Marks
# 195   3.82  12.06
# 196   7.40  33.41
# 197   9.02  44.03
# 198   8.93  46.20
# 199   7.91  46.93

# %%
df.describe()
# Out:
#             Hours       Marks
# count  200.000000  200.000000
# mean     5.098300   25.847350
# std      2.801152   14.677241
# min      0.550000    0.000000
# 25%      2.670000   12.585000
# 50%      5.195000   24.600000
# 75%      7.692500   38.987500
# max      9.880000   55.690000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   200 non-null    float64
#  1   Marks   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
list1=['Hours','Marks']

# %%
df[list1]=scaler.fit_transform(df[list1])

# %%
df.head()
# Out:
#       Hours     Marks
# 0 -0.371599 -0.611137
# 1  1.586069  1.568433
# 2  0.841654  0.879249
# 3  0.390711  0.104686
# 4 -1.116014 -0.451989

# %%
corre=df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corre, annot=True,cmap='coolwarm')
plt.show()

# %%
df.hist(figsize=(10,10),bins=10)
plt.show()

# %%
x_train = df[['Hours']]   # ✅ 2D (good)
y_train = df['Marks']     # ✅ 1D (good)

# %%
x
# Out:
# 0     -0.371599
# 1      1.586069
# 2      0.841654
# 3      0.390711
# 4     -1.116014
#          ...
# 195   -0.457493
# 196    0.823760
# 197    1.403544
# 198    1.371334
# 199    1.006285
# Name: Hours, Length: 200, dtype: float64

# %%
y
# Out:
# 0     -0.611137
# 1      1.568433
# 2      0.879249
# 3      0.104686
# 4     -0.451989
#          ...
# 195   -0.941727
# 196    0.516557
# 197    1.241942
# 198    1.390161
# 199    1.440022
# Name: Marks, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
lr_accuracy = r2_score(x_test,y_predict)*100

# %%
lr_accuracy
# Out:
# 99.69215153805214
